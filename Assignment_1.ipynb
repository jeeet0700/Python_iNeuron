# %% [markdown]
# 1. In the below elements which of them are values or an expression? eg:- values can be integer or string and expressions will be mathematical operators.

# %%
* mathematical operators
'hello' string
-87.8 float
- mathematical operators
/ mathematical operators
+ mathematical operators
6 integer

# %% [markdown]
# 2. What is the difference between string and variable?

# %%
String : it is a datatype, it contain information
Variable : it help us to stored information
x="iNeuron"
here x is varaible & "iNeuron" is string

# %% [markdown]
# 3. Describe three different data types.

# %%
3 diffrent datatype are
int
float
string

# %% [markdown]
# 4. What is an expression made up of? What do all expressions do?

# %%
An expression is a combination of values, variables, operators.
It evaluates the expression and displays the result.

# %% [markdown]
# 5. This assignment statements, like spam = 10. What is the difference between an expression and a statement?

# %%
A statement performs some action such as printing values, looping, or if statement. 
On the other hand, expressions also produce values and we can assign these values to new variables

# %% [markdown]
# 6. After running the following code, what does the variable bacon contain?
# bacon = 22
# bacon + 1

# %%
23

# %% [markdown]
# 7. What should the values of the following two terms be?
# 'spam' + 'spamspam'
# 'spam' * 3

# %%
'spam' + 'spamspam'
# Out:
# 'spamspamspam'

# %%
'spam' * 3
# Out:
# 'spamspamspam'

# %% [markdown]
# 8. Why is eggs a valid variable name while 100 is invalid?

# %%
while is the reserved keyword, while eggs is not reserved, while is use for loop implementation

# %% [markdown]
# 9. What three functions can be used to get the integer, floating-point number, or string version of a value?

# %%
int()
float()
str()

# %% [markdown]
# 10. Why does this expression cause an error? How can you fix it?
# 'I have eaten ' + 99 + ' burritos.'

# %%
'I have eaten ' + '99' + ' burritos.'
#concation is only possible when there is str.
# Out:
# 'I have eaten 99 burritos.'
