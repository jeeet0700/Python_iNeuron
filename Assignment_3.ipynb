# %% [markdown]
# 1. Why are functions advantageous to have in your programs?

# %%
Function are the set/rule of program that perform certain task, 
suppos if we want ro use certain type of task need to perform muktiple time, the
we need to wright the code multiple time. So in that case funtion help us to reduce it to 
wright multiple time

# %% [markdown]
# 2. When does the code in a function run: when it's specified or when it's called?

# %%
def run():
    print("Hello")

# %%
run() #function calling
# Out:
# Hello

# %% [markdown]
# 3. What statement creates a function?

# %%
def fun_name():

# %% [markdown]
# 4. What is the difference between a function and a function call?

# %%
below is funtion
def fun_name():
    print("Hello World")
    
below is funtion call
fun_name()
# Out:
# Hello World

# %% [markdown]
# 5. How many global scopes are there in a Python program? How many local scopes?

# %%
1 Global scopes
infinite Local scopes

# %% [markdown]
# 6. What happens to variables in a local scope when the function call returns?

# %%
def my_fun():
    a,b=10,20
    return a+b
#here a & b are local variable

# %%
my_fun()
# Out:
# 30

# %% [markdown]
# 7. What is the concept of a return value? Is it possible to have a return value in an expression?

# %%
return is a value that a function returns to the calling script or function when it completes its task
yes it is possible to return value in an expression
eg : return a+b

# %% [markdown]
# 8. If a function does not have a return statement, what is the return value of a call to that function?

# %%
NoneType

# %% [markdown]
# 9. How do you make a function variable refer to the global variable?

# %%
""""If you want to refer to a global variable in a function, 
you can use the global keyword to declare which variables are global."""

a=10
def my_fun():
    print(a)
    
#here a in global variable

# %%
my_fun()
# Out:
# 10

# %% [markdown]
# 10. What is the data type of None?

# %%
NoneType

# %% [markdown]
# 11. What does the sentence import areallyourpetsnamederic do?

# %%
import statement imports a module named areallyourpetsnamederic

# %%
import will import a module name areallyourpetsnamederic

# %% [markdown]
# 12. If you had a bacon() feature in a spam module, what would you call it after importing spam?

# %%
This function can be called with spam.bacon()

# %% [markdown]
# 13. What can you do to save a programme from crashing if it encounters an error?

# %%
we will use try except in code

# %% [markdown]
# 14. What is the purpose of the try clause? What is the purpose of the except clause?

# %%
try : while exceuting any code, adn we are not sure about it success run, in that case we
    will use try block
    
except : if try executed with any error then except block will run, except block run and give us the output.
